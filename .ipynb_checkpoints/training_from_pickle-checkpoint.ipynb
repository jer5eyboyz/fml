# %%
import pickle 
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.cross_validation import StratifiedKFold
from sklearn.feature_selection import RFECV

files = []
# files.append('2010_2017_original_sample.p')
# files.append('2010_2017_down_sample.p')
# files.append('2010_2017_up_sample.p')
files.append('pickles/2017_original_sample_100_feature.p')
files.append('pickles/2017_down_sample_100_feature.p')
files.append('pickles/2017_up_sample_100_feature.p')

for file in files:
    data = pd.read_pickle(file)
    print(file, data.shape)
    Y = data['class'].values
    data = data.drop(['class'],axis=1) 
    X = data.values
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y)
    
    
    ####original####
    clf.fit(X_train,Y_train)
    Ascores_Train = cross_val_score(clf, X_train, Y_train, cv=5)
    Ascores_Test = clf.score(X_test,Y_test)

    print ("LogisticRegression L1")
    print('train score',Ascores_Train.mean()) 
    print('std',Ascores_Train.std()) 
    print('test score',Ascores_Test)
    
    
    ################## rfecv ##################
    clf = LogisticRegression(C=1.0, penalty='l1')
    rfecv = RFECV(estimator=clf, step=1, cv=StratifiedKFold(Y_train, 2),
                  scoring='accuracy')

    rfecv.fit(X_train, Y_train)
    print('##############')
    print(file, "original Optimal number of features : %d" % rfecv.n_features_)

    plt.figure()
    plt.xlabel("Number of features selected")
    plt.ylabel("Cross validation score (nb of correct classifications)")
    plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
    plt.show()
    
    Ascores_Test = rfecv.score(X_test,Y_test)

    print ("logistic regression l1 with feature selection")
    print('test score',Ascores_Test)
    print()
    importance = []
    ranking = []

    for i,x in enumerate(rfecv.support_):
        if x == True:
            importance.append(data.columns[i])

    print(importance)
    print()
# Out:
# pickles/2017_original_sample_100_feature.p (5926, 332)
# LogisticRegression L1
# train score 0.79973236055
# std 0.00697417846369
# test score 0.800944669366
# ##############
# pickles/2017_original_sample_100_feature.p original Optimal number of features : 306
# logistic regression l1 with feature selection
# test score 0.7995951417
#
# ['explicit', 'disc_number', 'track_number', 'tempo', 'key', 'loudness', 'mode', 'speechiness', 'liveness', 'valence', 'danceability', 'energy', 'duration_ms', 'time_signature', 'acousticness', 'instrumentalness', 'year', 'month', 'artist_genres_alternative', 'artist_genres_americana', 'artist_genres_anthem', 'artist_genres_banda', 'artist_genres_baroque', 'artist_genres_bass', 'artist_genres_big', 'artist_genres_blues', 'artist_genres_brostep', 'artist_genres_canadian', 'artist_genres_ccm', 'artist_genres_chamber', 'artist_genres_chillhop', 'artist_genres_chillwave', 'artist_genres_christian', 'artist_genres_christmas', 'artist_genres_classical', 'artist_genres_coast', 'artist_genres_contemporary', 'artist_genres_country', 'artist_genres_crunk', 'artist_genres_dance', 'artist_genres_deep', 'artist_genres_dirty', 'artist_genres_drill', 'artist_genres_dwn', 'artist_genres_edm', 'artist_genres_electro', 'artist_genres_electronic', 'artist_genres_emo', 'artist_genres_escape', 'artist_genres_fi', 'artist_genres_flow', 'artist_genres_focus', 'artist_genres_folk', 'artist_genres_freak', 'artist_genres_funk', 'artist_genres_gangster', 'artist_genres_garage', 'artist_genres_grunge', 'artist_genres_hardcore', 'artist_genres_hip', 'artist_genres_holler', 'artist_genres_hop', 'artist_genres_house', 'artist_genres_indie', 'artist_genres_indietronica', 'artist_genres_kit', 'artist_genres_latin', 'artist_genres_latino', 'artist_genres_lift', 'artist_genres_lo', 'artist_genres_mellow', 'artist_genres_metal', 'artist_genres_metalcore', 'artist_genres_metropopolis', 'artist_genres_mexican', 'artist_genres_modern', 'artist_genres_music', 'artist_genres_neo', 'artist_genres_new', 'artist_genres_norteno', 'artist_genres_nu', 'artist_genres_period', 'artist_genres_permanent', 'artist_genres_pop', 'artist_genres_poptimism', 'artist_genres_post', 'artist_genres_progressive', 'artist_genres_psych', 'artist_genres_psychedelic', 'artist_genres_punk', 'artist_genres_rap', 'artist_genres_reggaeton', 'artist_genres_regional', 'artist_genres_road', 'artist_genres_rock', 'artist_genres_romantic', 'artist_genres_room', 'artist_genres_roots', 'artist_genres_screamo', 'artist_genres_shimmer', 'artist_genres_singer', 'artist_genres_songwriter', 'artist_genres_soul', 'artist_genres_south', 'artist_genres_southern', 'artist_genres_stomp', 'artist_genres_synthpop', 'artist_genres_teen', 'artist_genres_trance', 'artist_genres_trap', 'artist_genres_tropical', 'artist_genres_twitch', 'artist_genres_underground', 'artist_genres_urban', 'artist_genres_vapor', 'artist_genres_viral', 'artist_genres_wave', 'artist_genres_worship', 'album_name_album', 'album_name_baby', 'album_name_bach', 'album_name_back', 'album_name_beast', 'album_name_beautiful', 'album_name_boy', 'album_name_cambridge', 'album_name_cello', 'album_name_chapel', 'album_name_christmas', 'album_name_could', 'album_name_cozy', 'album_name_de', 'album_name_decade', 'album_name_dedication', 'album_name_deluxe', 'album_name_dorilla', 'album_name_double', 'album_name_dram', 'album_name_edition', 'album_name_el', 'album_name_en', 'album_name_ep', 'album_name_episode', 'album_name_feat', 'album_name_feel', 'album_name_full', 'album_name_future', 'album_name_girls', 'album_name_good', 'album_name_greatest', 'album_name_heartbreak', 'album_name_hits', 'album_name_ii', 'album_name_know', 'album_name_la', 'album_name_life', 'album_name_like', 'album_name_live', 'album_name_long', 'album_name_losses', 'album_name_love', 'album_name_luv', 'album_name_moon', 'album_name_motion', 'album_name_mozart', 'album_name_music', 'album_name_night', 'album_name_nos', 'album_name_nothing', 'album_name_one', 'album_name_organ', 'album_name_original', 'album_name_para', 'album_name_people', 'album_name_picture', 'album_name_playlist', 'album_name_project', 'album_name_pt', 'album_name_rage', 'album_name_remix', 'album_name_remixes', 'album_name_rv', 'album_name_sebastian', 'album_name_singles', 'album_name_sleep', 'album_name_soundtr ...
# pickles/2017_down_sample_100_feature.p (2562, 332)
# LogisticRegression L1
# train score 0.72099089906
# std 0.0157563515701
# test score 0.745709828393
